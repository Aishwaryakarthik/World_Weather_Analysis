# %%
#Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from citipy import citipy

# %% [markdown]
# # Retrieving the Nearest City

# %%
#Create a set of 2,000 random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
coordinates = list(lat_lngs)

cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 759

# %% [markdown]
# # # Performing an API Call with the OpenWeatherMap

# %%
#Import dependencies
import requests
from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | thilogne
# City not found. Skipping...
# Processing Record 2 of Set 1 | port hardy
# Processing Record 3 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 1 | tuktoyaktuk
# Processing Record 5 of Set 1 | the valley
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | egvekinot
# Processing Record 8 of Set 1 | hobart
# Processing Record 9 of Set 1 | punta arenas
# Processing Record 10 of Set 1 | kodiak
# Processing Record 11 of Set 1 | bethel
# Processing Record 12 of Set 1 | iqaluit
# Processing Record 13 of Set 1 | sept-iles
# Processing Record 14 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 15 of Set 1 | cape town
# Processing Record 16 of Set 1 | gisborne
# Processing Record 17 of Set 1 | puerto leguizamo
# Processing Record 18 of Set 1 | thompson
# Processing Record 19 of Set 1 | pacific grove
# Processing Record 20 of Set 1 | faanui
# Processing Record 21 of Set 1 | sao felipe
# Processing Record 22 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 23 of Set 1 | cidreira
# Processing Record 24 of Set 1 | ancud
# Processing Record 25 of Set 1 | a
# City not found. Skipping...
# Processing Record 26 of Set 1 | pevek
# Processing Record 27 of Set 1 | valley city
# Processing Record 28 of Set 1 | ippy
# Processing Record 29 of Set 1 | port elizabeth
# Processing Record 30 of Set 1 | ugoofaaru
# Processing Record 31 of Set 1 | ninghai
# Processing Record 32 of Set 1 | albany
# Processing Record 33 of Set 1 | mataura
# Processing Record 34 of Set 1 | la ronge
# Processing Record 35 of Set 1 | castro
# Processing Record 36 of Set 1 | khatanga
# Processing Record 37 of Set 1 | pangkalanbuun
# Processing Record 38 of Set 1 | tiksi
# Processing Record 39 of Set 1 | lewistown
# Processing Record 40 of Set 1 | busselton
# Processing Record 41 of Set 1 | itarema
# Processing Record 42 of Set 1 | falealupo
# City not found. Skipping...
# Processing Record 43 of Set 1 | saskylakh
# Processing Record 44 of Set 1 | umm kaddadah
# Processing Record 45 of Set 1 | atar
# Processing Record 46 of Set 1 | puerto ayora
# Processing Record 47 of Set 1 | port alfred
# Processing Record 48 of Set 1 | vaini
# Processing Record 49 of Set 1 | lucapa
# Processing Record 50 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 1 of Set 2 | cabo san lucas
# Processing Record 2 of Set 2 | cedar city
# Processing Record 3 of Set 2 | aksu
# Processing Record 4 of Set 2 | tottori
# Processing Record 5 of Set 2 | andapa
# Processing Record 6 of Set 2 | lincoln
# Processing Record 7 of Set 2 | mosalsk
# Processing Record 8 of Set 2 | elko
# Processing Record 9 of Set 2 | sao filipe
# Processing Record 10 of Set 2 | aloleng
# Processing Record 11 of Set 2 | upernavik
# Processing Record 12 of Set 2 | narsaq
# Processing Record 13 of Set 2 | lithakia
# Processing Record 14 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 15 of Set 2 | nikolskoye
# Processing Record 16 of Set 2 | pedernales
# Processing Record 17 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 19 of Set 2 | alberton
# Processing Record 20 of Set 2 | tromso
# Processing Record 21 of Set 2 | peachland
# Processing Record 22 of Set 2 | chapais
# Processing Record 23 of Set 2 | kapaa
# Processing Record 24 of Set 2 | yeoryiani
# City not found. Skipping...
# Processing Record 25 of Set 2 | klaksvik
# Processing Record 26 of Set 2 | husavik
# Processing Record 27 of Set 2 | imbituba
# Processing Record 28 of Set 2 | talcahuano
# Processing Record 29 of Set 2 | midland
# Processing Record 30 of Set 2 | nome
# Processing Record 31 of Set 2 | berlevag
# Processing Record 32 of Set 2 | charters towers
# Processing Record 33 of Set 2 | kropotkin
# Processing Record 34 of Set 2 | tarauaca
# Processing Record 35 of Set 2 | motygino
# Processing Record 36 of Set 2 | nanortalik
# Processing Record 37 of Set 2 | san vicente
# Processing Record 38 of Set 2 | grande prairie
# Processing Record 39 of Set 2 | rikitea
# Processing Record 40 of Set 2 | burnie
# Processing Record 41 of Set 2 | bengkulu
# Processing Record 42 of Set 2 | atuona
# Processing Record 43 of Set 2 | new norfolk
# Processing Record 44 of Set 2 | yellowknife
# Processing Record 45 of Set 2 | tvoroyri
# Processing Record 46 of Set 2 | sitka
# Processing Record 47 of Set 2 | hanzhong
# Processing Record 48 of Set 2 | sabang
# Processing Record 49 of Set 2 | lakes entrance
# Processing Record 50 of Set 2 | necochea
# Processing Record 1 of Set 3 | saint-philippe
# Processing Record 2 of Set 3 | vermilion
# Processing Record 3 of Set 3 | huejuquilla el alto
# Processing Record 4 of Set 3 | kuytun
# Processing Record 5 of Set 3 | gainesville
# Processing Record 6 of Set 3 | hithadhoo
# Processing Record 7 of Set 3 | jamestown
# Processing Record 8 of Set 3 | mentok
# City not found. Skipping...
# Processing Record 9 of Set 3 | rantepao
# Processing Record 10 of Set 3 | pangoa
# Processing Record 11 of Set 3 | faya
# Processing Record 12 of Set 3 | santa cruz
# Processing Record 13 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 14 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 15 of Set 3 | whitehorse
# Processing Record 16 of Set 3 | naze
# Processing Record 17 of Set 3 | cherskiy
# Processing Record 18 of Set 3 | jining
# Processing Record 19 of Set 3 | butaritari
# Processing Record 20 of Set 3 | isangel
# Processing Record 21 of Set 3 | carnarvon
# Processing Record 22 of Set 3 | saint anthony
# Processing Record 23 of Set 3 | cockburn town
# Processing Record 24 of Set 3 | luderitz
# Processing Record 25 of Set 3 | qaanaaq
# Processing Record 26 of Set 3 | athens
# Processing Record 27 of Set 3 | touros
# Processing Record 28 of Set 3 | ilulissat
# Processing Record 29 of Set 3 | ribeira grande
# Processing Record 30 of Set 3 | sakakah
# Processing Record 31 of Set 3 | bredasdorp
# Processing Record 32 of Set 3 | westport
# Processing Record 33 of Set 3 | bambous virieux
# Processing Record 34 of Set 3 | santa isabel do rio negro
# Processing Record 35 of Set 3 | kayerkan
# Processing Record 36 of Set 3 | esperance
# Processing Record 37 of Set 3 | saint-pierre
# Processing Record 38 of Set 3 | balaipungut
# Processing Record 39 of Set 3 | warmbad
# Processing Record 40 of Set 3 | lavrentiya
# Processing Record 41 of Set 3 | east london
# Processing Record 42 of Set 3 | stepnoye
# Processing Record 43 of Set 3 | basoko
# Processing Record 44 of Set 3 | mar del plata
# Processing Record 45 of Set 3 | orgun
# City not found. Skipping...
# Processing Record 46 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 47 of Set 3 | chenghai
# Processing Record 48 of Set 3 | avarua
# Processing Record 49 of Set 3 | seymchan
# Processing Record 50 of Set 3 | chokurdakh
# Processing Record 1 of Set 4 | geraldton
# Processing Record 2 of Set 4 | dikson
# Processing Record 3 of Set 4 | bathsheba
# Processing Record 4 of Set 4 | talnakh
# Processing Record 5 of Set 4 | svetlogorsk
# Processing Record 6 of Set 4 | codrington
# Processing Record 7 of Set 4 | bluff
# Processing Record 8 of Set 4 | maceio
# Processing Record 9 of Set 4 | longyearbyen
# Processing Record 10 of Set 4 | omboue
# Processing Record 11 of Set 4 | inta
# Processing Record 12 of Set 4 | zehdenick
# Processing Record 13 of Set 4 | aklavik
# Processing Record 14 of Set 4 | tasiilaq
# Processing Record 15 of Set 4 | havoysund
# Processing Record 16 of Set 4 | arraial do cabo
# Processing Record 17 of Set 4 | marzuq
# Processing Record 18 of Set 4 | broome
# Processing Record 19 of Set 4 | hami
# Processing Record 20 of Set 4 | hervey bay
# Processing Record 21 of Set 4 | nim ka thana
# City not found. Skipping...
# Processing Record 22 of Set 4 | urdzhar
# City not found. Skipping...
# Processing Record 23 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 24 of Set 4 | yirol
# City not found. Skipping...
# Processing Record 25 of Set 4 | zigong
# Processing Record 26 of Set 4 | tambura
# Processing Record 27 of Set 4 | porto de moz
# Processing Record 28 of Set 4 | hamilton
# Processing Record 29 of Set 4 | caraquet
# Processing Record 30 of Set 4 | pilar
# Processing Record 31 of Set 4 | solnechnyy
# Processing Record 32 of Set 4 | cayeli
# Processing Record 33 of Set 4 | aasiaat
# Processing Record 34 of Set 4 | north bend
# Processing Record 35 of Set 4 | norman wells
# Processing Record 36 of Set 4 | port keats
# Processing Record 37 of Set 4 | hermanus
# Processing Record 38 of Set 4 | dera bugti
# Processing Record 39 of Set 4 | stornoway
# Processing Record 40 of Set 4 | ubauro
# Processing Record 41 of Set 4 | te anau
# Processing Record 42 of Set 4 | half moon bay
# Processing Record 43 of Set 4 | gouyave
# Processing Record 44 of Set 4 | chuy
# Processing Record 45 of Set 4 | puerto quijarro
# Processing Record 46 of Set 4 | adjumani
# Processing Record 47 of Set 4 | kokkola
# Processing Record 48 of Set 4 | linxia
# Processing Record 49 of Set 4 | aksarka
# Processing Record 50 of Set 4 | solovetskiy
# City not found. Skipping...
# Processing Record 1 of Set 5 | handwara
# City not found. Skipping...
# Processing Record 2 of Set 5 | luau
# Processing Record 3 of Set 5 | maner
# Processing Record 4 of Set 5 | bubaque
# Processing Record 5 of Set 5 | sawang daen din
# Processing Record 6 of Set 5 | oranjemund
# Processing Record 7 of Set 5 | saint-georges
# Processing Record 8 of Set 5 | lata
# Processing Record 9 of Set 5 | port macquarie
# Processing Record 10 of Set 5 | provideniya
# Processing Record 11 of Set 5 | hilo
# Processing Record 12 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 13 of Set 5 | champerico
# Processing Record 14 of Set 5 | general roca
# Processing Record 15 of Set 5 | kipushi
# Processing Record 16 of Set 5 | den helder
# Processing Record 17 of Set 5 | gurmatkal
# Processing Record 18 of Set 5 | puerto madero
# Processing Record 19 of Set 5 | leningradskiy
# Processing Record 20 of Set 5 | ponta do sol
# Processing Record 21 of Set 5 | sobolevo
# Processing Record 22 of Set 5 | laguna
# Processing Record 23 of Set 5 | burgeo
# Processing Record 24 of Set 5 | saint-joseph
# Processing Record 25 of Set 5 | natal
# Processing Record 26 of Set 5 | namibe
# Processing Record 27 of Set 5 | kutum
# Processing Record 28 of Set 5 | lagoa
# Processing Record 29 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 30 of Set 5 | snezhnogorsk
# Processing Record 31 of Set 5 | marawi
# Processing Record 32 of Set 5 | pauini
# Processing Record 33 of Set 5 | beringovskiy
# Processing Record 34 of Set 5 | mangai
# Processing Record 35 of Set 5 | terrasini
# Processing Record 36 of Set 5 | coihaique
# Processing Record 37 of Set 5 | srednekolymsk
# Processing Record 38 of Set 5 | kapit
# Processing Record 39 of Set 5 | barrow
# Processing Record 40 of Set 5 | airai
# Processing Record 41 of Set 5 | muros
# Processing Record 42 of Set 5 | tura
# Processing Record 43 of Set 5 | murgab
# Processing Record 44 of Set 5 | georgetown
# Processing Record 45 of Set 5 | kruisfontein
# Processing Record 46 of Set 5 | clyde river
# Processing Record 47 of Set 5 | kiunga
# Processing Record 48 of Set 5 | raymond terrace
# Processing Record 49 of Set 5 | ijaki
# City not found. Skipping...
# Processing Record 50 of Set 5 | pozoblanco
# Processing Record 1 of Set 6 | port lincoln
# Processing Record 2 of Set 6 | turukhansk
# Processing Record 3 of Set 6 | okha
# Processing Record 4 of Set 6 | kollam
# Processing Record 5 of Set 6 | groton
# Processing Record 6 of Set 6 | vardo
# Processing Record 7 of Set 6 | waterfoot
# Processing Record 8 of Set 6 | broken hill
# Processing Record 9 of Set 6 | beaufort
# Processing Record 10 of Set 6 | vao
# Processing Record 11 of Set 6 | manokwari
# Processing Record 12 of Set 6 | mandurah
# Processing Record 13 of Set 6 | celestun
# Processing Record 14 of Set 6 | semnan
# Processing Record 15 of Set 6 | gorno-altaysk
# Processing Record 16 of Set 6 | tual
# Processing Record 17 of Set 6 | pato branco
# Processing Record 18 of Set 6 | amursk
# Processing Record 19 of Set 6 | santa vitoria do palmar
# Processing Record 20 of Set 6 | fairbanks
# Processing Record 21 of Set 6 | xiangdong
# City not found. Skipping...
# Processing Record 22 of Set 6 | lake city
# Processing Record 23 of Set 6 | katsuura
# Processing Record 24 of Set 6 | paso de los toros
# Processing Record 25 of Set 6 | bonthe
# Processing Record 26 of Set 6 | fortuna
# Processing Record 27 of Set 6 | sisimiut
# Processing Record 28 of Set 6 | vila franca do campo
# Processing Record 29 of Set 6 | lima
# Processing Record 30 of Set 6 | ditzingen
# Processing Record 31 of Set 6 | sioux lookout
# Processing Record 32 of Set 6 | alingsas
# Processing Record 33 of Set 6 | osmanabad
# Processing Record 34 of Set 6 | constitucion
# Processing Record 35 of Set 6 | nanchang
# Processing Record 36 of Set 6 | tifton
# Processing Record 37 of Set 6 | port-gentil
# Processing Record 38 of Set 6 | ambatondrazaka
# Processing Record 39 of Set 6 | tuatapere
# Processing Record 40 of Set 6 | tambun
# Processing Record 41 of Set 6 | lebu
# Processing Record 42 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 43 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 44 of Set 6 | san cristobal
# Processing Record 45 of Set 6 | ca mau
# Processing Record 46 of Set 6 | banjar
# Processing Record 47 of Set 6 | severobaykalsk
# Processing Record 48 of Set 6 | adrar
# Processing Record 49 of Set 6 | severo-kurilsk
# Processing Record 50 of Set 6 | gushikawa
# Processing Record 1 of Set 7 | coihueco
# Processing Record 2 of Set 7 | mount isa
# Processing Record 3 of Set 7 | new port richey
# Processing Record 4 of Set 7 | lorengau
# Processing Record 5 of Set 7 | kavaratti
# Processing Record 6 of Set 7 | kaitangata
# Processing Record 7 of Set 7 | yangjiang
# Processing Record 8 of Set 7 | nambucca heads
# Processing Record 9 of Set 7 | florida
# Processing Record 10 of Set 7 | sovetskaya gavan
# Processing Record 11 of Set 7 | mujiayingzi
# Processing Record 12 of Set 7 | nelson bay
# Processing Record 13 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 14 of Set 7 | moron
# Processing Record 15 of Set 7 | santiago del estero
# Processing Record 16 of Set 7 | ruatoria
# City not found. Skipping...
# Processing Record 17 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 7 | cam ranh
# Processing Record 19 of Set 7 | camacha
# Processing Record 20 of Set 7 | pokhara
# Processing Record 21 of Set 7 | dobrany
# Processing Record 22 of Set 7 | macaubas
# Processing Record 23 of Set 7 | mayo
# Processing Record 24 of Set 7 | seabra
# Processing Record 25 of Set 7 | qui nhon
# Processing Record 26 of Set 7 | areosa
# Processing Record 27 of Set 7 | gasa
# Processing Record 28 of Set 7 | vieques
# Processing Record 29 of Set 7 | zonguldak
# Processing Record 30 of Set 7 | ormara
# Processing Record 31 of Set 7 | chicama
# Processing Record 32 of Set 7 | baymak
# Processing Record 33 of Set 7 | nassau
# Processing Record 34 of Set 7 | taihe
# Processing Record 35 of Set 7 | saint-louis
# Processing Record 36 of Set 7 | talara
# Processing Record 37 of Set 7 | agadez
# Processing Record 38 of Set 7 | olafsvik
# Processing Record 39 of Set 7 | antalaha
# Processing Record 40 of Set 7 | novopokrovka
# Processing Record 41 of Set 7 | shagonar
# Processing Record 42 of Set 7 | arica
# Processing Record 43 of Set 7 | huilong
# Processing Record 44 of Set 7 | ostrovnoy
# Processing Record 45 of Set 7 | le havre
# Processing Record 46 of Set 7 | fukue
# Processing Record 47 of Set 7 | denpasar
# Processing Record 48 of Set 7 | umm lajj
# Processing Record 49 of Set 7 | saint george
# Processing Record 50 of Set 7 | tremembe
# Processing Record 1 of Set 8 | victoria
# Processing Record 2 of Set 8 | aljezur
# Processing Record 3 of Set 8 | santa ana huista
# Processing Record 4 of Set 8 | ghanzi
# Processing Record 5 of Set 8 | hasaki
# Processing Record 6 of Set 8 | kloulklubed
# Processing Record 7 of Set 8 | matara
# Processing Record 8 of Set 8 | kailua
# Processing Record 9 of Set 8 | victor harbor
# Processing Record 10 of Set 8 | caravelas
# Processing Record 11 of Set 8 | turayf
# Processing Record 12 of Set 8 | bezenchuk
# Processing Record 13 of Set 8 | komsomolskiy
# Processing Record 14 of Set 8 | saint-leu
# Processing Record 15 of Set 8 | portobelo
# Processing Record 16 of Set 8 | manoel urbano
# Processing Record 17 of Set 8 | alim
# Processing Record 18 of Set 8 | mabaruma
# Processing Record 19 of Set 8 | davila
# Processing Record 20 of Set 8 | tiznit
# Processing Record 21 of Set 8 | batemans bay
# Processing Record 22 of Set 8 | palmer
# Processing Record 23 of Set 8 | chumikan
# Processing Record 24 of Set 8 | dongying
# Processing Record 25 of Set 8 | marsh harbour
# Processing Record 26 of Set 8 | sao joao da barra
# Processing Record 27 of Set 8 | turka
# Processing Record 28 of Set 8 | torbay
# Processing Record 29 of Set 8 | chabahar
# Processing Record 30 of Set 8 | chifeng
# Processing Record 31 of Set 8 | varna
# Processing Record 32 of Set 8 | santa maria
# Processing Record 33 of Set 8 | sigli
# Processing Record 34 of Set 8 | saint-francois
# Processing Record 35 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 36 of Set 8 | kenai
# Processing Record 37 of Set 8 | kathmandu
# Processing Record 38 of Set 8 | simpang
# Processing Record 39 of Set 8 | bambanglipuro
# Processing Record 40 of Set 8 | filingue
# Processing Record 41 of Set 8 | baykit
# Processing Record 42 of Set 8 | henties bay
# Processing Record 43 of Set 8 | jasper
# Processing Record 44 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 45 of Set 8 | yatou
# Processing Record 46 of Set 8 | portree
# Processing Record 47 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 48 of Set 8 | sorland
# Processing Record 49 of Set 8 | bilma
# Processing Record 50 of Set 8 | requena
# Processing Record 1 of Set 9 | gagnoa
# Processing Record 2 of Set 9 | aquiraz
# Processing Record 3 of Set 9 | kasongo-lunda
# Processing Record 4 of Set 9 | yaan
# Processing Record 5 of Set 9 | hirara
# Processing Record 6 of Set 9 | waingapu
# Processing Record 7 of Set 9 | camanducaia
# Processing Record 8 of Set 9 | koroni
# Processing Record 9 of Set 9 | san pedro
# Processing Record 10 of Set 9 | algarrobo
# Processing Record 11 of Set 9 | birao
# Processing Record 12 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 13 of Set 9 | buqayq
# City not found. Skipping...
# Processing Record 14 of Set 9 | malwan
# City not found. Skipping...
# Processing Record 15 of Set 9 | kudahuvadhoo
# Processing Record 16 of Set 9 | sao jose da coroa grande
# Processing Record 17 of Set 9 | kavieng
# Processing Record 18 of Set 9 | kaiu
# Processing Record 19 of Set 9 | ambilobe
# Processing Record 20 of Set 9 | emerald
# Processing Record 21 of Set 9 | tomatlan
# Processing Record 22 of Set 9 | skjervoy
# Processing Record 23 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 24 of Set 9 | inderborskiy
# City not found. Skipping...
# Processing Record 25 of Set 9 | oksfjord
# Processing Record 26 of Set 9 | vila velha
# Processing Record 27 of Set 9 | miri
# Processing Record 28 of Set 9 | ambulu
# Processing Record 29 of Set 9 | sofiysk
# City not found. Skipping...
# Processing Record 30 of Set 9 | ures
# Processing Record 31 of Set 9 | stokmarknes
# Processing Record 32 of Set 9 | ahipara
# Processing Record 33 of Set 9 | lasa
# Processing Record 34 of Set 9 | hay river
# Processing Record 35 of Set 9 | camacupa
# Processing Record 36 of Set 9 | fujin
# Processing Record 37 of Set 9 | manbij
# Processing Record 38 of Set 9 | nagaur
# Processing Record 39 of Set 9 | port shepstone
# Processing Record 40 of Set 9 | jalu
# Processing Record 41 of Set 9 | berbera
# Processing Record 42 of Set 9 | reconquista
# Processing Record 43 of Set 9 | monrovia
# Processing Record 44 of Set 9 | noumea
# Processing Record 45 of Set 9 | mareeba
# Processing Record 46 of Set 9 | cayambe
# Processing Record 47 of Set 9 | formoso do araguaia
# City not found. Skipping...
# Processing Record 48 of Set 9 | hayvoron
# Processing Record 49 of Set 9 | puerto cabezas
# Processing Record 50 of Set 9 | sola
# Processing Record 1 of Set 10 | duz
# City not found. Skipping...
# Processing Record 2 of Set 10 | qingdao
# Processing Record 3 of Set 10 | linhares
# Processing Record 4 of Set 10 | ronne
# Processing Record 5 of Set 10 | livingston
# Processing Record 6 of Set 10 | sylvan lake
# Processing Record 7 of Set 10 | dubbo
# Processing Record 8 of Set 10 | bontang
# Processing Record 9 of Set 10 | kenora
# Processing Record 10 of Set 10 | gzhatsk
# City not found. Skipping...
# Processing Record 11 of Set 10 | manaure
# Processing Record 12 of Set 10 | keti bandar
# Processing Record 13 of Set 10 | bambamarca
# Processing Record 14 of Set 10 | pleshanovo
# Processing Record 15 of Set 10 | porbandar
# Processing Record 16 of Set 10 | ramshir
# Processing Record 17 of Set 10 | kondopoga
# Processing Record 18 of Set 10 | tambilil
# Processing Record 19 of Set 10 | mahebourg
# Processing Record 20 of Set 10 | madera
# Processing Record 21 of Set 10 | honningsvag
# Processing Record 22 of Set 10 | rawson
# Processing Record 23 of Set 10 | yining
# Processing Record 24 of Set 10 | korla
# Processing Record 25 of Set 10 | tautira
# Processing Record 26 of Set 10 | porto velho
# Processing Record 27 of Set 10 | nouadhibou
# Processing Record 28 of Set 10 | kjollefjord
# Processing Record 29 of Set 10 | chuguyevka
# Processing Record 30 of Set 10 | rincon
# Processing Record 31 of Set 10 | digby
# Processing Record 32 of Set 10 | yanan
# City not found. Skipping...
# Processing Record 33 of Set 10 | leskovac
# Processing Record 34 of Set 10 | san patricio
# Processing Record 35 of Set 10 | toul
# Processing Record 36 of Set 10 | yar-sale
# Processing Record 37 of Set 10 | gat
# Processing Record 38 of Set 10 | dukat
# Processing Record 39 of Set 10 | lar gerd
# City not found. Skipping...
# Processing Record 40 of Set 10 | dindori
# Processing Record 41 of Set 10 | we
# City not found. Skipping...
# Processing Record 42 of Set 10 | tuy hoa
# Processing Record 43 of Set 10 | mount gambier
# Processing Record 44 of Set 10 | itoman
# Processing Record 45 of Set 10 | magalia
# Processing Record 46 of Set 10 | beloha
# Processing Record 47 of Set 10 | saint-augustin
# Processing Record 48 of Set 10 | suntar
# Processing Record 49 of Set 10 | shingu
# Processing Record 50 of Set 10 | balsas
# Processing Record 1 of Set 11 | maldonado
# Processing Record 2 of Set 11 | pisco
# Processing Record 3 of Set 11 | hakkari
# Processing Record 4 of Set 11 | leh
# Processing Record 5 of Set 11 | zverinogolovskoye
# Processing Record 6 of Set 11 | galgani
# City not found. Skipping...
# Processing Record 7 of Set 11 | nola
# Processing Record 8 of Set 11 | elizabeth city
# Processing Record 9 of Set 11 | zhangye
# Processing Record 10 of Set 11 | price
# Processing Record 11 of Set 11 | petrovskaya
# Processing Record 12 of Set 11 | rudbar
# Processing Record 13 of Set 11 | hobyo
# Processing Record 14 of Set 11 | kieta
# Processing Record 15 of Set 11 | tabou
# Processing Record 16 of Set 11 | belaya gora
# Processing Record 17 of Set 11 | eureka
# Processing Record 18 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 19 of Set 11 | ossora
# Processing Record 20 of Set 11 | llata
# Processing Record 21 of Set 11 | abu samrah
# Processing Record 22 of Set 11 | zhigansk
# Processing Record 23 of Set 11 | harper
# Processing Record 24 of Set 11 | margate
# Processing Record 25 of Set 11 | barra patuca
# Processing Record 26 of Set 11 | safwah
# City not found. Skipping...
# Processing Record 27 of Set 11 | ponta delgada
# Processing Record 28 of Set 11 | baena
# Processing Record 29 of Set 11 | reinosa
# Processing Record 30 of Set 11 | puerto escondido
# Processing Record 31 of Set 11 | meulaboh
# Processing Record 32 of Set 11 | minden
# Processing Record 33 of Set 11 | erdenet
# Processing Record 34 of Set 11 | saint-ambroise
# Processing Record 35 of Set 11 | vila
# Processing Record 36 of Set 11 | dwarka
# Processing Record 37 of Set 11 | nombre de dios
# Processing Record 38 of Set 11 | port moresby
# Processing Record 39 of Set 11 | mineros
# Processing Record 40 of Set 11 | tidore
# City not found. Skipping...
# Processing Record 41 of Set 11 | poso
# Processing Record 42 of Set 11 | frohnleiten
# Processing Record 43 of Set 11 | pedro juan caballero
# Processing Record 44 of Set 11 | pemberton
# Processing Record 45 of Set 11 | kathu
# Processing Record 46 of Set 11 | ovre ardal
# Processing Record 47 of Set 11 | souillac
# Processing Record 48 of Set 11 | portland
# Processing Record 49 of Set 11 | dhidhdhoo
# Processing Record 50 of Set 11 | wewak
# Processing Record 1 of Set 12 | guozhen
# Processing Record 2 of Set 12 | soe
# Processing Record 3 of Set 12 | hailey
# Processing Record 4 of Set 12 | aktau
# Processing Record 5 of Set 12 | solton
# Processing Record 6 of Set 12 | bloomfield
# Processing Record 7 of Set 12 | fort dodge
# Processing Record 8 of Set 12 | nikita
# Processing Record 9 of Set 12 | novyy buyan
# Processing Record 10 of Set 12 | bafilo
# Processing Record 11 of Set 12 | rosarito
# Processing Record 12 of Set 12 | sapa
# Processing Record 13 of Set 12 | skelleftea
# Processing Record 14 of Set 12 | naro
# Processing Record 15 of Set 12 | roma
# Processing Record 16 of Set 12 | saldanha
# Processing Record 17 of Set 12 | zhanaozen
# Processing Record 18 of Set 12 | biak
# Processing Record 19 of Set 12 | havelock
# Processing Record 20 of Set 12 | maxixe
# Processing Record 21 of Set 12 | udachnyy
# Processing Record 22 of Set 12 | polunochnoye
# Processing Record 23 of Set 12 | mehamn
# Processing Record 24 of Set 12 | bilibino
# Processing Record 25 of Set 12 | zakamensk
# Processing Record 26 of Set 12 | agadir
# Processing Record 27 of Set 12 | manta
# Processing Record 28 of Set 12 | buraydah
# Processing Record 29 of Set 12 | svobodnyy
# Processing Record 30 of Set 12 | naryan-mar
# Processing Record 31 of Set 12 | vanderhoof
# Processing Record 32 of Set 12 | semenyih
# Processing Record 33 of Set 12 | sargatskoye
# Processing Record 34 of Set 12 | ambon
# Processing Record 35 of Set 12 | dunedin
# Processing Record 36 of Set 12 | altus
# Processing Record 37 of Set 12 | presidente medici
# Processing Record 38 of Set 12 | kharp
# Processing Record 39 of Set 12 | churapcha
# Processing Record 40 of Set 12 | vanimo
# Processing Record 41 of Set 12 | utiroa
# City not found. Skipping...
# Processing Record 42 of Set 12 | bhadrapur
# Processing Record 43 of Set 12 | tokur
# Processing Record 44 of Set 12 | candelaria
# Processing Record 45 of Set 12 | abnub
# Processing Record 46 of Set 12 | tsihombe
# City not found. Skipping...
# Processing Record 47 of Set 12 | ertil
# Processing Record 48 of Set 12 | altea
# Processing Record 49 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 50 of Set 12 | doka
# Processing Record 1 of Set 13 | jacareacanga
# Processing Record 2 of Set 13 | pangai
# Processing Record 3 of Set 13 | dakoro
# Processing Record 4 of Set 13 | sao joao do piaui
# Processing Record 5 of Set 13 | krasnyy yar
# Processing Record 6 of Set 13 | alofi
# Processing Record 7 of Set 13 | kaeo
# Processing Record 8 of Set 13 | garowe
# Processing Record 9 of Set 13 | abashiri
# Processing Record 10 of Set 13 | chute-aux-outardes
# Processing Record 11 of Set 13 | salalah
# Processing Record 12 of Set 13 | samaipata
# Processing Record 13 of Set 13 | guerrero negro
# Processing Record 14 of Set 13 | wajima
# Processing Record 15 of Set 13 | bainbridge
# Processing Record 16 of Set 13 | curvelo
# Processing Record 17 of Set 13 | boa vista
# Processing Record 18 of Set 13 | honiara
# Processing Record 19 of Set 13 | cabra
# Processing Record 20 of Set 13 | bandarbeyla
# Processing Record 21 of Set 13 | boysun
# Processing Record 22 of Set 13 | cabinda
# Processing Record 23 of Set 13 | barawe
# City not found. Skipping...
# Processing Record 24 of Set 13 | ovalle
# Processing Record 25 of Set 13 | pontes e lacerda
# Processing Record 26 of Set 13 | koumac
# Processing Record 27 of Set 13 | svarstad
# Processing Record 28 of Set 13 | qarqin
# Processing Record 29 of Set 13 | iralaya
# Processing Record 30 of Set 13 | codajas
# Processing Record 31 of Set 13 | mayuge
# Processing Record 32 of Set 13 | japura
# Processing Record 33 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 34 of Set 13 | bulgan
# Processing Record 35 of Set 13 | sfantu gheorghe
# Processing Record 36 of Set 13 | sao miguel do araguaia
# Processing Record 37 of Set 13 | arawa
# Processing Record 38 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 39 of Set 13 | kpandae
# Processing Record 40 of Set 13 | torzhok
# Processing Record 41 of Set 13 | les cayes
# Processing Record 42 of Set 13 | benguela
# Processing Record 43 of Set 13 | pemangkat
# Processing Record 44 of Set 13 | los llanos de aridane
# Processing Record 45 of Set 13 | praia
# Processing Record 46 of Set 13 | grimshaw
# Processing Record 47 of Set 13 | namatanai
# Processing Record 48 of Set 13 | urucui
# Processing Record 49 of Set 13 | okato
# Processing Record 50 of Set 13 | mayya
# Processing Record 1 of Set 14 | alotau
# City not found. Skipping...
# Processing Record 2 of Set 14 | belyy yar
# Processing Record 3 of Set 14 | natchez
# Processing Record 4 of Set 14 | brandon
# Processing Record 5 of Set 14 | comodoro rivadavia
# Processing Record 6 of Set 14 | kousseri
# Processing Record 7 of Set 14 | falmouth
# Processing Record 8 of Set 14 | upington
# Processing Record 9 of Set 14 | marrakesh
# Processing Record 10 of Set 14 | samana
# Processing Record 11 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 12 of Set 14 | planeta rica
# Processing Record 13 of Set 14 | tezu
# Processing Record 14 of Set 14 | machali
# Processing Record 15 of Set 14 | kununurra
# Processing Record 16 of Set 14 | loreto
# Processing Record 17 of Set 14 | gamba
# Processing Record 18 of Set 14 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 19 of Set 14 | chililabombwe
# Processing Record 20 of Set 14 | preeceville
# Processing Record 21 of Set 14 | dingle
# Processing Record 22 of Set 14 | lagos
# Processing Record 23 of Set 14 | paamiut
# Processing Record 24 of Set 14 | port hedland
# Processing Record 25 of Set 14 | flinders
# Processing Record 26 of Set 14 | aykhal
# Processing Record 27 of Set 14 | maarianhamina
# Processing Record 28 of Set 14 | college
# Processing Record 29 of Set 14 | bad sassendorf
# Processing Record 30 of Set 14 | porto belo
# Processing Record 31 of Set 14 | deputatskiy
# Processing Record 32 of Set 14 | rabaul
# Processing Record 33 of Set 14 | christchurch
# Processing Record 34 of Set 14 | san quintin
# Processing Record 35 of Set 14 | birin
# Processing Record 36 of Set 14 | kimi
# City not found. Skipping...
# Processing Record 37 of Set 14 | vung tau
# Processing Record 38 of Set 14 | koscierzyna
# Processing Record 39 of Set 14 | el alto
# Processing Record 40 of Set 14 | orikum
# Processing Record 41 of Set 14 | banjarmasin
# Processing Record 42 of Set 14 | lompoc
# Processing Record 43 of Set 14 | huarmey
# Processing Record 44 of Set 14 | san ramon
# Processing Record 45 of Set 14 | kamenka
# Processing Record 46 of Set 14 | nicoya
# Processing Record 47 of Set 14 | goulburn
# Processing Record 48 of Set 14 | khalabat
# Processing Record 49 of Set 14 | tinskoy
# Processing Record 50 of Set 14 | neuquen
# Processing Record 1 of Set 15 | kirakira
# Processing Record 2 of Set 15 | lithgow
# Processing Record 3 of Set 15 | dafeng
# Processing Record 4 of Set 15 | coahuayana
# Processing Record 5 of Set 15 | waipawa
# Processing Record 6 of Set 15 | madingou
# Processing Record 7 of Set 15 | yerbogachen
# Processing Record 8 of Set 15 | riyadh
# Processing Record 9 of Set 15 | fevralsk
# City not found. Skipping...
# Processing Record 10 of Set 15 | coolum beach
# Processing Record 11 of Set 15 | ngorongoro
# Processing Record 12 of Set 15 | gunjur
# Processing Record 13 of Set 15 | brigantine
# Processing Record 14 of Set 15 | santo estevao
# Processing Record 15 of Set 15 | roald
# Processing Record 16 of Set 15 | tyret pervaya
# Processing Record 17 of Set 15 | puerto ayacucho
# Processing Record 18 of Set 15 | tucuma
# Processing Record 19 of Set 15 | dakar
# Processing Record 20 of Set 15 | juru
# Processing Record 21 of Set 15 | barcelos
# Processing Record 22 of Set 15 | changji
# Processing Record 23 of Set 15 | sao paulo de olivenca
# Processing Record 24 of Set 15 | mago
# Processing Record 25 of Set 15 | sligo
# Processing Record 26 of Set 15 | xiaoweizhai
# Processing Record 27 of Set 15 | tete
# Processing Record 28 of Set 15 | telde
# Processing Record 29 of Set 15 | kuryk
# Processing Record 30 of Set 15 | maragogi
# Processing Record 31 of Set 15 | cap-aux-meules
# Processing Record 32 of Set 15 | atasu
# Processing Record 33 of Set 15 | san luis
# Processing Record 34 of Set 15 | vysokogornyy
# Processing Record 35 of Set 15 | surgut
# Processing Record 36 of Set 15 | tagusao
# Processing Record 37 of Set 15 | moose factory
# Processing Record 38 of Set 15 | verkhnyaya inta
# Processing Record 39 of Set 15 | senneterre
# Processing Record 40 of Set 15 | richards bay
# Processing Record 41 of Set 15 | junin
# Processing Record 42 of Set 15 | pitea
# Processing Record 43 of Set 15 | hofn
# Processing Record 44 of Set 15 | kahului
# Processing Record 45 of Set 15 | chermoz
# Processing Record 46 of Set 15 | kismayo
# Processing Record 47 of Set 15 | tiarei
# Processing Record 48 of Set 15 | biograd na moru
# Processing Record 49 of Set 15 | gulshat
# City not found. Skipping...
# Processing Record 50 of Set 15 | kijang
# Processing Record 1 of Set 16 | okhotsk
# Processing Record 2 of Set 16 | haines junction
# Processing Record 3 of Set 16 | seoul
# Processing Record 4 of Set 16 | valday
# Processing Record 5 of Set 16 | vanavara
# Processing Record 6 of Set 16 | tipuani
# Processing Record 7 of Set 16 | saint-denis
# Processing Record 8 of Set 16 | labuan
# Processing Record 9 of Set 16 | sao luiz gonzaga
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 698

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Port Hardy      CA  50.6996 -127.4199     41.00        93          75
# 1   Tuktoyaktuk      CA  69.4541 -133.0374    -27.40        68          20
# 2    The Valley      AI  18.2170  -63.0578     84.06        61          20
# 3       Ushuaia      AR -54.8000  -68.3000     46.02        70          20
# 4     Egvekinot      RU  66.3167 -179.1667    -11.83        87          15
# 5        Hobart      AU -42.8794  147.3294     56.26        94         100
# 6  Punta Arenas      CL -53.1500  -70.9167     44.71        70          20
# 7        Kodiak      US  57.7900 -152.4072     27.91        86           0
# 8        Bethel      US  41.3712  -73.4140     45.68        82         100
# 9       Iqaluit      CA  63.7506  -68.5145     26.33        86          75
#
#    Wind Speed   Current Description
# 0        5.75         broken clouds
# 1        4.61            few clouds
# 2       17.27            few clouds
# 3       18.41            few clouds
# 4       19.19            few clouds
# 5        6.91       overcast clouds
# 6       29.93            few clouds
# 7        5.75             clear sky
# 8        3.44  heavy intensity rain
# 9       23.02         broken clouds

# %%
output_data_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label='City_ID')
