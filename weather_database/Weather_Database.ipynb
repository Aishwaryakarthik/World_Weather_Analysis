# %%
#Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from citipy import citipy

# %% [markdown]
# # Retrieving the Nearest City

# %%
#Create a set of 2,000 random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
coordinates = list(lat_lngs)

cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 786

# %% [markdown]
# # # Performing an API Call with the OpenWeatherMap

# %%
#Import dependencies
import requests
from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | alofi
# Processing Record 2 of Set 1 | barcelos
# Processing Record 3 of Set 1 | aksarka
# Processing Record 4 of Set 1 | busselton
# Processing Record 5 of Set 1 | deputatskiy
# Processing Record 6 of Set 1 | puerto carreno
# Processing Record 7 of Set 1 | san cristobal
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | avarua
# Processing Record 10 of Set 1 | murchison
# Processing Record 11 of Set 1 | iqaluit
# Processing Record 12 of Set 1 | longavi
# Processing Record 13 of Set 1 | castro
# Processing Record 14 of Set 1 | talnakh
# Processing Record 15 of Set 1 | kosa
# Processing Record 16 of Set 1 | telemaco borba
# Processing Record 17 of Set 1 | cockburn town
# Processing Record 18 of Set 1 | kaili
# Processing Record 19 of Set 1 | barrow
# Processing Record 20 of Set 1 | ushuaia
# Processing Record 21 of Set 1 | yellowknife
# Processing Record 22 of Set 1 | chengde
# Processing Record 23 of Set 1 | vaini
# Processing Record 24 of Set 1 | bluff
# Processing Record 25 of Set 1 | moerai
# Processing Record 26 of Set 1 | atuona
# Processing Record 27 of Set 1 | port-gentil
# Processing Record 28 of Set 1 | puerto ayora
# Processing Record 29 of Set 1 | hobart
# Processing Record 30 of Set 1 | albany
# Processing Record 31 of Set 1 | butaritari
# Processing Record 32 of Set 1 | thompson
# Processing Record 33 of Set 1 | sept-iles
# Processing Record 34 of Set 1 | gibsons
# Processing Record 35 of Set 1 | shimoda
# Processing Record 36 of Set 1 | rikitea
# Processing Record 37 of Set 1 | buckeye
# Processing Record 38 of Set 1 | faanui
# Processing Record 39 of Set 1 | hithadhoo
# Processing Record 40 of Set 1 | great yarmouth
# Processing Record 41 of Set 1 | sitka
# Processing Record 42 of Set 1 | myrtle beach
# Processing Record 43 of Set 1 | kologriv
# Processing Record 44 of Set 1 | weinan
# Processing Record 45 of Set 1 | mar del plata
# Processing Record 46 of Set 1 | zhigansk
# Processing Record 47 of Set 1 | kapaa
# Processing Record 48 of Set 1 | nagato
# Processing Record 49 of Set 1 | provideniya
# Processing Record 50 of Set 1 | belaya gora
# Processing Record 1 of Set 2 | victoria
# Processing Record 2 of Set 2 | balikpapan
# Processing Record 3 of Set 2 | porbandar
# Processing Record 4 of Set 2 | pevek
# Processing Record 5 of Set 2 | dakar
# Processing Record 6 of Set 2 | khatanga
# Processing Record 7 of Set 2 | comodoro rivadavia
# Processing Record 8 of Set 2 | remanso
# Processing Record 9 of Set 2 | jamestown
# Processing Record 10 of Set 2 | ponta do sol
# Processing Record 11 of Set 2 | la paz
# Processing Record 12 of Set 2 | kodiak
# Processing Record 13 of Set 2 | harrison
# Processing Record 14 of Set 2 | souillac
# Processing Record 15 of Set 2 | tondano
# Processing Record 16 of Set 2 | cape town
# Processing Record 17 of Set 2 | port lincoln
# Processing Record 18 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 19 of Set 2 | ouegoa
# Processing Record 20 of Set 2 | okhotsk
# Processing Record 21 of Set 2 | nanortalik
# Processing Record 22 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 23 of Set 2 | fortuna
# Processing Record 24 of Set 2 | le vauclin
# Processing Record 25 of Set 2 | durusu
# Processing Record 26 of Set 2 | batesville
# Processing Record 27 of Set 2 | upernavik
# Processing Record 28 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 29 of Set 2 | lebu
# Processing Record 30 of Set 2 | hilo
# Processing Record 31 of Set 2 | salalah
# Processing Record 32 of Set 2 | sisimiut
# Processing Record 33 of Set 2 | vagur
# Processing Record 34 of Set 2 | teya
# Processing Record 35 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 36 of Set 2 | komsomolskiy
# Processing Record 37 of Set 2 | sant feliu de guixols
# Processing Record 38 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 39 of Set 2 | bischofshofen
# Processing Record 40 of Set 2 | kaitangata
# Processing Record 41 of Set 2 | lompoc
# Processing Record 42 of Set 2 | kazalinsk
# City not found. Skipping...
# Processing Record 43 of Set 2 | new norfolk
# Processing Record 44 of Set 2 | tyrma
# Processing Record 45 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 46 of Set 2 | norman wells
# Processing Record 47 of Set 2 | bredasdorp
# Processing Record 48 of Set 2 | mataura
# Processing Record 49 of Set 2 | tasiilaq
# Processing Record 50 of Set 2 | rovaniemi
# Processing Record 1 of Set 3 | mount isa
# Processing Record 2 of Set 3 | dikson
# Processing Record 3 of Set 3 | viedma
# Processing Record 4 of Set 3 | nome
# Processing Record 5 of Set 3 | hermanus
# Processing Record 6 of Set 3 | mitzic
# Processing Record 7 of Set 3 | bambous virieux
# Processing Record 8 of Set 3 | shubarkuduk
# Processing Record 9 of Set 3 | hasanabad
# Processing Record 10 of Set 3 | alta floresta
# Processing Record 11 of Set 3 | broome
# Processing Record 12 of Set 3 | asau
# Processing Record 13 of Set 3 | yeppoon
# Processing Record 14 of Set 3 | semey
# Processing Record 15 of Set 3 | matagami
# Processing Record 16 of Set 3 | nikolskoye
# Processing Record 17 of Set 3 | ipora
# Processing Record 18 of Set 3 | luderitz
# Processing Record 19 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 20 of Set 3 | ulladulla
# Processing Record 21 of Set 3 | nelson bay
# Processing Record 22 of Set 3 | port elizabeth
# Processing Record 23 of Set 3 | saldanha
# Processing Record 24 of Set 3 | meadow lake
# Processing Record 25 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 26 of Set 3 | carmen
# Processing Record 27 of Set 3 | burgstadt
# Processing Record 28 of Set 3 | meulaboh
# Processing Record 29 of Set 3 | yulara
# Processing Record 30 of Set 3 | miracema do tocantins
# Processing Record 31 of Set 3 | harper
# Processing Record 32 of Set 3 | qaanaaq
# Processing Record 33 of Set 3 | diego de almagro
# Processing Record 34 of Set 3 | jiuquan
# Processing Record 35 of Set 3 | marsabit
# Processing Record 36 of Set 3 | saint-pacome
# City not found. Skipping...
# Processing Record 37 of Set 3 | pastrana
# Processing Record 38 of Set 3 | narsaq
# Processing Record 39 of Set 3 | plettenberg bay
# Processing Record 40 of Set 3 | carnarvon
# Processing Record 41 of Set 3 | one hundred mile house
# City not found. Skipping...
# Processing Record 42 of Set 3 | cajati
# Processing Record 43 of Set 3 | sao filipe
# Processing Record 44 of Set 3 | skagastrond
# City not found. Skipping...
# Processing Record 45 of Set 3 | ocos
# Processing Record 46 of Set 3 | lamu
# Processing Record 47 of Set 3 | port alfred
# Processing Record 48 of Set 3 | kalmunai
# Processing Record 49 of Set 3 | virginia beach
# Processing Record 50 of Set 3 | evensk
# Processing Record 1 of Set 4 | claresholm
# Processing Record 2 of Set 4 | georgetown
# Processing Record 3 of Set 4 | ribeira grande
# Processing Record 4 of Set 4 | cabo san lucas
# Processing Record 5 of Set 4 | saint-philippe
# Processing Record 6 of Set 4 | tuktoyaktuk
# Processing Record 7 of Set 4 | hasaki
# Processing Record 8 of Set 4 | buala
# Processing Record 9 of Set 4 | ponta delgada
# Processing Record 10 of Set 4 | ajaccio
# Processing Record 11 of Set 4 | mehamn
# Processing Record 12 of Set 4 | sri aman
# Processing Record 13 of Set 4 | garoua boulai
# Processing Record 14 of Set 4 | ust-omchug
# Processing Record 15 of Set 4 | sioux lookout
# Processing Record 16 of Set 4 | cap malheureux
# Processing Record 17 of Set 4 | clyde river
# Processing Record 18 of Set 4 | minas de barroteran
# Processing Record 19 of Set 4 | muravlenko
# Processing Record 20 of Set 4 | lima
# Processing Record 21 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 22 of Set 4 | zyryanka
# Processing Record 23 of Set 4 | arraial do cabo
# Processing Record 24 of Set 4 | santa rosa
# Processing Record 25 of Set 4 | skjervoy
# Processing Record 26 of Set 4 | cidreira
# Processing Record 27 of Set 4 | aklavik
# Processing Record 28 of Set 4 | abalak
# Processing Record 29 of Set 4 | bloemfontein
# Processing Record 30 of Set 4 | mandalgovi
# Processing Record 31 of Set 4 | sladkovo
# Processing Record 32 of Set 4 | el jicaro
# Processing Record 33 of Set 4 | merrill
# Processing Record 34 of Set 4 | shitanjing
# Processing Record 35 of Set 4 | paamiut
# Processing Record 36 of Set 4 | eyl
# Processing Record 37 of Set 4 | bathsheba
# Processing Record 38 of Set 4 | puerto el triunfo
# Processing Record 39 of Set 4 | pisco
# Processing Record 40 of Set 4 | yichun
# Processing Record 41 of Set 4 | tuggurt
# City not found. Skipping...
# Processing Record 42 of Set 4 | beruwala
# Processing Record 43 of Set 4 | isangel
# Processing Record 44 of Set 4 | takob
# City not found. Skipping...
# Processing Record 45 of Set 4 | hambantota
# Processing Record 46 of Set 4 | kansanshi
# Processing Record 47 of Set 4 | lata
# Processing Record 48 of Set 4 | haibowan
# City not found. Skipping...
# Processing Record 49 of Set 4 | pangody
# Processing Record 50 of Set 4 | chuy
# Processing Record 1 of Set 5 | issoudun
# Processing Record 2 of Set 5 | nuevo progreso
# Processing Record 3 of Set 5 | carupano
# Processing Record 4 of Set 5 | ugoofaaru
# Processing Record 5 of Set 5 | tapaua
# City not found. Skipping...
# Processing Record 6 of Set 5 | hamilton
# Processing Record 7 of Set 5 | pahrump
# Processing Record 8 of Set 5 | lavrentiya
# Processing Record 9 of Set 5 | antalaha
# Processing Record 10 of Set 5 | olafsvik
# Processing Record 11 of Set 5 | bemidji
# Processing Record 12 of Set 5 | vanimo
# Processing Record 13 of Set 5 | catuday
# Processing Record 14 of Set 5 | olinda
# Processing Record 15 of Set 5 | khilok
# Processing Record 16 of Set 5 | saquena
# Processing Record 17 of Set 5 | samalaeulu
# City not found. Skipping...
# Processing Record 18 of Set 5 | presidencia roque saenz pena
# Processing Record 19 of Set 5 | mandla
# Processing Record 20 of Set 5 | waitati
# Processing Record 21 of Set 5 | redencao
# Processing Record 22 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 23 of Set 5 | hvammstangi
# City not found. Skipping...
# Processing Record 24 of Set 5 | saint george
# Processing Record 25 of Set 5 | east london
# Processing Record 26 of Set 5 | correia pinto
# Processing Record 27 of Set 5 | palora
# Processing Record 28 of Set 5 | kholm
# Processing Record 29 of Set 5 | byron bay
# Processing Record 30 of Set 5 | dukat
# Processing Record 31 of Set 5 | hualmay
# Processing Record 32 of Set 5 | mayo
# Processing Record 33 of Set 5 | julio de castilhos
# Processing Record 34 of Set 5 | nouadhibou
# Processing Record 35 of Set 5 | chicama
# Processing Record 36 of Set 5 | balkanabat
# Processing Record 37 of Set 5 | margate
# Processing Record 38 of Set 5 | saint anthony
# Processing Record 39 of Set 5 | airai
# Processing Record 40 of Set 5 | salinas
# Processing Record 41 of Set 5 | sur
# Processing Record 42 of Set 5 | san quintin
# Processing Record 43 of Set 5 | severodvinsk
# Processing Record 44 of Set 5 | ghanzi
# Processing Record 45 of Set 5 | corowa
# Processing Record 46 of Set 5 | kaberamaido
# Processing Record 47 of Set 5 | vao
# Processing Record 48 of Set 5 | cortez
# Processing Record 49 of Set 5 | anahuac
# Processing Record 50 of Set 5 | slave lake
# Processing Record 1 of Set 6 | sao felix do xingu
# Processing Record 2 of Set 6 | carauari
# Processing Record 3 of Set 6 | necochea
# Processing Record 4 of Set 6 | lumby
# Processing Record 5 of Set 6 | vila
# Processing Record 6 of Set 6 | laizhou
# Processing Record 7 of Set 6 | cherskiy
# Processing Record 8 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 9 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 10 of Set 6 | vardo
# Processing Record 11 of Set 6 | kudahuvadhoo
# Processing Record 12 of Set 6 | shelburne
# Processing Record 13 of Set 6 | chipinge
# Processing Record 14 of Set 6 | turochak
# Processing Record 15 of Set 6 | bethel
# Processing Record 16 of Set 6 | poopo
# Processing Record 17 of Set 6 | mahibadhoo
# Processing Record 18 of Set 6 | tchollire
# Processing Record 19 of Set 6 | rincon
# Processing Record 20 of Set 6 | senneterre
# Processing Record 21 of Set 6 | tautira
# Processing Record 22 of Set 6 | ryotsu
# Processing Record 23 of Set 6 | khandyga
# Processing Record 24 of Set 6 | henties bay
# Processing Record 25 of Set 6 | qovlar
# Processing Record 26 of Set 6 | qaqortoq
# Processing Record 27 of Set 6 | santona
# Processing Record 28 of Set 6 | caravelas
# Processing Record 29 of Set 6 | hofn
# Processing Record 30 of Set 6 | sofiysk
# City not found. Skipping...
# Processing Record 31 of Set 6 | longyearbyen
# Processing Record 32 of Set 6 | fairbanks
# Processing Record 33 of Set 6 | ola
# Processing Record 34 of Set 6 | valleyview
# Processing Record 35 of Set 6 | sarkand
# Processing Record 36 of Set 6 | kavaratti
# Processing Record 37 of Set 6 | mayumba
# Processing Record 38 of Set 6 | mahebourg
# Processing Record 39 of Set 6 | torbay
# Processing Record 40 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 41 of Set 6 | kawalu
# Processing Record 42 of Set 6 | codrington
# Processing Record 43 of Set 6 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 44 of Set 6 | adrar
# Processing Record 45 of Set 6 | ostrovnoy
# Processing Record 46 of Set 6 | pandan
# Processing Record 47 of Set 6 | saskylakh
# Processing Record 48 of Set 6 | asyut
# Processing Record 49 of Set 6 | gushikawa
# Processing Record 50 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 1 of Set 7 | jibuti
# Processing Record 2 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 3 of Set 7 | trelew
# Processing Record 4 of Set 7 | nemuro
# Processing Record 5 of Set 7 | manadhoo
# Processing Record 6 of Set 7 | udachnyy
# Processing Record 7 of Set 7 | serra talhada
# Processing Record 8 of Set 7 | mount gambier
# Processing Record 9 of Set 7 | leningradskiy
# Processing Record 10 of Set 7 | verkhniye tatyshly
# Processing Record 11 of Set 7 | trat
# Processing Record 12 of Set 7 | muisne
# Processing Record 13 of Set 7 | port-cartier
# Processing Record 14 of Set 7 | takoradi
# Processing Record 15 of Set 7 | port hardy
# Processing Record 16 of Set 7 | imbituba
# Processing Record 17 of Set 7 | qasigiannguit
# Processing Record 18 of Set 7 | kutum
# Processing Record 19 of Set 7 | pareora
# Processing Record 20 of Set 7 | killybegs
# Processing Record 21 of Set 7 | nishihara
# Processing Record 22 of Set 7 | nogliki
# Processing Record 23 of Set 7 | guerrero negro
# Processing Record 24 of Set 7 | hendaye
# Processing Record 25 of Set 7 | beyneu
# Processing Record 26 of Set 7 | chokurdakh
# Processing Record 27 of Set 7 | kuala kangsar
# Processing Record 28 of Set 7 | somvarpet
# Processing Record 29 of Set 7 | lorengau
# Processing Record 30 of Set 7 | micheweni
# Processing Record 31 of Set 7 | tokur
# Processing Record 32 of Set 7 | maneadero
# Processing Record 33 of Set 7 | buraydah
# Processing Record 34 of Set 7 | okato
# Processing Record 35 of Set 7 | natal
# Processing Record 36 of Set 7 | singleton
# Processing Record 37 of Set 7 | geraldton
# Processing Record 38 of Set 7 | nago
# Processing Record 39 of Set 7 | yerbogachen
# Processing Record 40 of Set 7 | privolzhskiy
# Processing Record 41 of Set 7 | shetpe
# Processing Record 42 of Set 7 | pitimbu
# Processing Record 43 of Set 7 | nuuk
# Processing Record 44 of Set 7 | broken hill
# Processing Record 45 of Set 7 | mana
# Processing Record 46 of Set 7 | tutoia
# Processing Record 47 of Set 7 | biak
# Processing Record 48 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 49 of Set 7 | klaksvik
# Processing Record 50 of Set 7 | senmonorom
# City not found. Skipping...
# Processing Record 1 of Set 8 | fort nelson
# Processing Record 2 of Set 8 | cogealac
# Processing Record 3 of Set 8 | oneonta
# Processing Record 4 of Set 8 | jalu
# Processing Record 5 of Set 8 | ust-kut
# Processing Record 6 of Set 8 | lishu
# Processing Record 7 of Set 8 | atlantic city
# Processing Record 8 of Set 8 | carolina
# Processing Record 9 of Set 8 | ahipara
# Processing Record 10 of Set 8 | severo-kurilsk
# Processing Record 11 of Set 8 | pombas
# Processing Record 12 of Set 8 | itapirapua
# Processing Record 13 of Set 8 | mandali
# Processing Record 14 of Set 8 | oussouye
# Processing Record 15 of Set 8 | buchanan
# Processing Record 16 of Set 8 | anuradhapura
# Processing Record 17 of Set 8 | lagos
# Processing Record 18 of Set 8 | puerto escondido
# Processing Record 19 of Set 8 | urengoy
# Processing Record 20 of Set 8 | zhangye
# Processing Record 21 of Set 8 | pinega
# Processing Record 22 of Set 8 | sal rei
# Processing Record 23 of Set 8 | richards bay
# Processing Record 24 of Set 8 | gillette
# Processing Record 25 of Set 8 | ulaangom
# Processing Record 26 of Set 8 | mwense
# Processing Record 27 of Set 8 | san patricio
# Processing Record 28 of Set 8 | toftir
# City not found. Skipping...
# Processing Record 29 of Set 8 | cheremnoye
# Processing Record 30 of Set 8 | portland
# Processing Record 31 of Set 8 | bria
# Processing Record 32 of Set 8 | ixtapa
# Processing Record 33 of Set 8 | tsienyane
# City not found. Skipping...
# Processing Record 34 of Set 8 | hutang
# Processing Record 35 of Set 8 | ketchikan
# Processing Record 36 of Set 8 | les herbiers
# Processing Record 37 of Set 8 | tuatapere
# Processing Record 38 of Set 8 | lasa
# Processing Record 39 of Set 8 | puertollano
# Processing Record 40 of Set 8 | puerto madero
# Processing Record 41 of Set 8 | rafraf
# Processing Record 42 of Set 8 | nandyal
# Processing Record 43 of Set 8 | trincomalee
# Processing Record 44 of Set 8 | inhambane
# Processing Record 45 of Set 8 | port hedland
# Processing Record 46 of Set 8 | srednekolymsk
# Processing Record 47 of Set 8 | vila franca do campo
# Processing Record 48 of Set 8 | samarai
# Processing Record 49 of Set 8 | okahandja
# Processing Record 50 of Set 8 | alice springs
# Processing Record 1 of Set 9 | ranfurly
# Processing Record 2 of Set 9 | anito
# Processing Record 3 of Set 9 | pitiquito
# Processing Record 4 of Set 9 | kavieng
# Processing Record 5 of Set 9 | santa isabel do rio negro
# Processing Record 6 of Set 9 | bairiki
# Processing Record 7 of Set 9 | davidson
# Processing Record 8 of Set 9 | kuytun
# Processing Record 9 of Set 9 | abu dhabi
# Processing Record 10 of Set 9 | ukiah
# Processing Record 11 of Set 9 | mitsamiouli
# Processing Record 12 of Set 9 | keetmanshoop
# Processing Record 13 of Set 9 | bireun
# Processing Record 14 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 15 of Set 9 | pauini
# Processing Record 16 of Set 9 | batagay
# Processing Record 17 of Set 9 | nanakuli
# Processing Record 18 of Set 9 | mathbaria
# Processing Record 19 of Set 9 | the pas
# Processing Record 20 of Set 9 | maniitsoq
# Processing Record 21 of Set 9 | aswan
# Processing Record 22 of Set 9 | salcininkai
# Processing Record 23 of Set 9 | jurado
# Processing Record 24 of Set 9 | dibaya
# City not found. Skipping...
# Processing Record 25 of Set 9 | half moon bay
# Processing Record 26 of Set 9 | yuxia
# Processing Record 27 of Set 9 | vila velha
# Processing Record 28 of Set 9 | katsuura
# Processing Record 29 of Set 9 | harer
# Processing Record 30 of Set 9 | makokou
# Processing Record 31 of Set 9 | coihaique
# Processing Record 32 of Set 9 | rolla
# Processing Record 33 of Set 9 | plattsburgh
# Processing Record 34 of Set 9 | palm valley
# Processing Record 35 of Set 9 | nizhneangarsk
# Processing Record 36 of Set 9 | la ronge
# Processing Record 37 of Set 9 | lazaro cardenas
# Processing Record 38 of Set 9 | vestmanna
# Processing Record 39 of Set 9 | constitucion
# Processing Record 40 of Set 9 | bengkulu
# Processing Record 41 of Set 9 | syracuse
# Processing Record 42 of Set 9 | fallon
# Processing Record 43 of Set 9 | chimbote
# Processing Record 44 of Set 9 | saint-pierre
# Processing Record 45 of Set 9 | ranong
# Processing Record 46 of Set 9 | panaba
# Processing Record 47 of Set 9 | yuancheng
# Processing Record 48 of Set 9 | christchurch
# Processing Record 49 of Set 9 | kaseda
# Processing Record 50 of Set 9 | ancud
# Processing Record 1 of Set 10 | buriti
# Processing Record 2 of Set 10 | tura
# Processing Record 3 of Set 10 | chara
# Processing Record 4 of Set 10 | palasa
# Processing Record 5 of Set 10 | grand centre
# City not found. Skipping...
# Processing Record 6 of Set 10 | kruisfontein
# Processing Record 7 of Set 10 | hay river
# Processing Record 8 of Set 10 | nara
# Processing Record 9 of Set 10 | troitskoye
# Processing Record 10 of Set 10 | moskovskiy
# Processing Record 11 of Set 10 | brae
# Processing Record 12 of Set 10 | mwinilunga
# Processing Record 13 of Set 10 | olkhovka
# Processing Record 14 of Set 10 | muroto
# Processing Record 15 of Set 10 | hrodna
# Processing Record 16 of Set 10 | touros
# Processing Record 17 of Set 10 | xining
# Processing Record 18 of Set 10 | newcastle
# Processing Record 19 of Set 10 | kaspiyskiy
# Processing Record 20 of Set 10 | kapit
# Processing Record 21 of Set 10 | angermunde
# Processing Record 22 of Set 10 | homer
# Processing Record 23 of Set 10 | lushunkou
# City not found. Skipping...
# Processing Record 24 of Set 10 | villanueva de cordoba
# Processing Record 25 of Set 10 | somerset
# Processing Record 26 of Set 10 | hobyo
# Processing Record 27 of Set 10 | perevoz
# Processing Record 28 of Set 10 | andenes
# Processing Record 29 of Set 10 | aluksne
# Processing Record 30 of Set 10 | newport
# Processing Record 31 of Set 10 | myanaung
# Processing Record 32 of Set 10 | salvador
# Processing Record 33 of Set 10 | abaza
# Processing Record 34 of Set 10 | riyadh
# Processing Record 35 of Set 10 | mahon
# Processing Record 36 of Set 10 | calama
# Processing Record 37 of Set 10 | skibbereen
# Processing Record 38 of Set 10 | nantucket
# Processing Record 39 of Set 10 | anloga
# Processing Record 40 of Set 10 | nevel
# Processing Record 41 of Set 10 | atar
# Processing Record 42 of Set 10 | qui nhon
# Processing Record 43 of Set 10 | itamarandiba
# Processing Record 44 of Set 10 | jinchang
# Processing Record 45 of Set 10 | igarka
# Processing Record 46 of Set 10 | port blair
# Processing Record 47 of Set 10 | wonthaggi
# Processing Record 48 of Set 10 | erenhot
# Processing Record 49 of Set 10 | saint simons
# Processing Record 50 of Set 10 | vryheid
# Processing Record 1 of Set 11 | ciudad bolivar
# Processing Record 2 of Set 11 | merida
# Processing Record 3 of Set 11 | rio gallegos
# Processing Record 4 of Set 11 | pangnirtung
# Processing Record 5 of Set 11 | dawlatabad
# Processing Record 6 of Set 11 | kamaishi
# Processing Record 7 of Set 11 | mangan
# Processing Record 8 of Set 11 | iquitos
# Processing Record 9 of Set 11 | senanga
# Processing Record 10 of Set 11 | fowa
# Processing Record 11 of Set 11 | santa maria
# Processing Record 12 of Set 11 | ayagoz
# Processing Record 13 of Set 11 | najran
# Processing Record 14 of Set 11 | siuna
# Processing Record 15 of Set 11 | pathein
# Processing Record 16 of Set 11 | suluova
# Processing Record 17 of Set 11 | vanavara
# Processing Record 18 of Set 11 | petrovsk
# Processing Record 19 of Set 11 | esperance
# Processing Record 20 of Set 11 | praia
# Processing Record 21 of Set 11 | ambon
# Processing Record 22 of Set 11 | the valley
# Processing Record 23 of Set 11 | aykhal
# Processing Record 24 of Set 11 | lahat
# Processing Record 25 of Set 11 | saint-joseph
# Processing Record 26 of Set 11 | salamiyah
# Processing Record 27 of Set 11 | keflavik
# Processing Record 28 of Set 11 | beringovskiy
# Processing Record 29 of Set 11 | cachoeira do sul
# Processing Record 30 of Set 11 | xichang
# Processing Record 31 of Set 11 | eureka
# Processing Record 32 of Set 11 | naze
# Processing Record 33 of Set 11 | lagoa
# Processing Record 34 of Set 11 | goderich
# Processing Record 35 of Set 11 | sola
# Processing Record 36 of Set 11 | sturgeon bay
# Processing Record 37 of Set 11 | khani
# Processing Record 38 of Set 11 | nyakahanga
# Processing Record 39 of Set 11 | peniche
# Processing Record 40 of Set 11 | mokhsogollokh
# Processing Record 41 of Set 11 | shirokiy
# Processing Record 42 of Set 11 | seoul
# Processing Record 43 of Set 11 | gazli
# Processing Record 44 of Set 11 | kitwe
# Processing Record 45 of Set 11 | santa cruz cabralia
# Processing Record 46 of Set 11 | lashio
# Processing Record 47 of Set 11 | hun
# Processing Record 48 of Set 11 | altay
# Processing Record 49 of Set 11 | fort-shevchenko
# Processing Record 50 of Set 11 | diu
# Processing Record 1 of Set 12 | nouakchott
# Processing Record 2 of Set 12 | baykit
# Processing Record 3 of Set 12 | ranot
# Processing Record 4 of Set 12 | frankenburg
# Processing Record 5 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 6 of Set 12 | talara
# Processing Record 7 of Set 12 | kahului
# Processing Record 8 of Set 12 | tangzhai
# Processing Record 9 of Set 12 | flinders
# Processing Record 10 of Set 12 | bridlington
# Processing Record 11 of Set 12 | povenets
# Processing Record 12 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 13 of Set 12 | sao joao da barra
# Processing Record 14 of Set 12 | charters towers
# Processing Record 15 of Set 12 | saint-leu
# Processing Record 16 of Set 12 | guanay
# Processing Record 17 of Set 12 | ucluelet
# Processing Record 18 of Set 12 | abha
# Processing Record 19 of Set 12 | fuerte
# Processing Record 20 of Set 12 | tayirove
# Processing Record 21 of Set 12 | padre bernardo
# Processing Record 22 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 23 of Set 12 | nexo
# Processing Record 24 of Set 12 | faya
# Processing Record 25 of Set 12 | general roca
# Processing Record 26 of Set 12 | mitu
# Processing Record 27 of Set 12 | patitirion
# Processing Record 28 of Set 12 | puerto madryn
# Processing Record 29 of Set 12 | kinablangan
# Processing Record 30 of Set 12 | saint austell
# Processing Record 31 of Set 12 | afyonkarahisar
# Processing Record 32 of Set 12 | hauterive
# Processing Record 33 of Set 12 | laguna
# Processing Record 34 of Set 12 | dolores
# Processing Record 35 of Set 12 | ganzhou
# Processing Record 36 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 37 of Set 12 | cayenne
# Processing Record 38 of Set 12 | phan rang
# City not found. Skipping...
# Processing Record 39 of Set 12 | saint-georges
# Processing Record 40 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 41 of Set 12 | taoudenni
# Processing Record 42 of Set 12 | atchison
# Processing Record 43 of Set 12 | mocuba
# Processing Record 44 of Set 12 | dicabisagan
# Processing Record 45 of Set 12 | sozimskiy
# Processing Record 46 of Set 12 | russell
# Processing Record 47 of Set 12 | tirukkattuppalli
# City not found. Skipping...
# Processing Record 48 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 49 of Set 12 | mandal
# Processing Record 50 of Set 12 | amahai
# Processing Record 1 of Set 13 | dauphin
# Processing Record 2 of Set 13 | avera
# Processing Record 3 of Set 13 | husavik
# Processing Record 4 of Set 13 | tual
# Processing Record 5 of Set 13 | kupang
# Processing Record 6 of Set 13 | pozo colorado
# Processing Record 7 of Set 13 | barawe
# City not found. Skipping...
# Processing Record 8 of Set 13 | alyangula
# Processing Record 9 of Set 13 | czestochowa
# Processing Record 10 of Set 13 | conde
# Processing Record 11 of Set 13 | taseyevo
# Processing Record 12 of Set 13 | goure
# Processing Record 13 of Set 13 | camacha
# Processing Record 14 of Set 13 | arawa
# Processing Record 15 of Set 13 | voh
# Processing Record 16 of Set 13 | river falls
# Processing Record 17 of Set 13 | verkhoyansk
# Processing Record 18 of Set 13 | longlac
# City not found. Skipping...
# Processing Record 19 of Set 13 | merritt
# Processing Record 20 of Set 13 | dauriya
# Processing Record 21 of Set 13 | coahuayana
# Processing Record 22 of Set 13 | lewiston
# Processing Record 23 of Set 13 | buariki
# City not found. Skipping...
# Processing Record 24 of Set 13 | bilma
# Processing Record 25 of Set 13 | camacupa
# Processing Record 26 of Set 13 | abu samrah
# Processing Record 27 of Set 13 | walvis bay
# Processing Record 28 of Set 13 | padang
# Processing Record 29 of Set 13 | rawson
# Processing Record 30 of Set 13 | nalhati
# Processing Record 31 of Set 13 | zeya
# Processing Record 32 of Set 13 | namibe
# Processing Record 33 of Set 13 | dossor
# Processing Record 34 of Set 13 | tiarei
# Processing Record 35 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 36 of Set 13 | cairns
# Processing Record 37 of Set 13 | port macquarie
# Processing Record 38 of Set 13 | sao jose da coroa grande
# Processing Record 39 of Set 13 | sinjah
# City not found. Skipping...
# Processing Record 40 of Set 13 | impfondo
# Processing Record 41 of Set 13 | hearst
# Processing Record 42 of Set 13 | bahraich
# Processing Record 43 of Set 13 | sobolevo
# Processing Record 44 of Set 13 | namatanai
# Processing Record 45 of Set 13 | acapulco
# Processing Record 46 of Set 13 | lensk
# Processing Record 47 of Set 13 | birao
# Processing Record 48 of Set 13 | portobelo
# Processing Record 49 of Set 13 | bacungan
# Processing Record 50 of Set 13 | saint-denis
# Processing Record 1 of Set 14 | general pico
# Processing Record 2 of Set 14 | zhuhai
# Processing Record 3 of Set 14 | pedasi
# Processing Record 4 of Set 14 | srikakulam
# Processing Record 5 of Set 14 | lahaina
# Processing Record 6 of Set 14 | dianopolis
# City not found. Skipping...
# Processing Record 7 of Set 14 | nkhata bay
# Processing Record 8 of Set 14 | amursk
# Processing Record 9 of Set 14 | bhiwani
# Processing Record 10 of Set 14 | almaznyy
# Processing Record 11 of Set 14 | constantine
# Processing Record 12 of Set 14 | karasjok
# Processing Record 13 of Set 14 | matsanga
# City not found. Skipping...
# Processing Record 14 of Set 14 | haines junction
# Processing Record 15 of Set 14 | halalo
# City not found. Skipping...
# Processing Record 16 of Set 14 | barwani
# Processing Record 17 of Set 14 | denpasar
# Processing Record 18 of Set 14 | belyy yar
# Processing Record 19 of Set 14 | hami
# Processing Record 20 of Set 14 | uglegorsk
# Processing Record 21 of Set 14 | altamont
# Processing Record 22 of Set 14 | wewak
# Processing Record 23 of Set 14 | pombal
# Processing Record 24 of Set 14 | ypsonas
# Processing Record 25 of Set 14 | matli
# Processing Record 26 of Set 14 | krishnarajasagara
# Processing Record 27 of Set 14 | abay
# Processing Record 28 of Set 14 | gympie
# Processing Record 29 of Set 14 | lincoln
# Processing Record 30 of Set 14 | big rapids
# Processing Record 31 of Set 14 | warrnambool
# Processing Record 32 of Set 14 | te anau
# Processing Record 33 of Set 14 | oskemen
# Processing Record 34 of Set 14 | grand forks
# Processing Record 35 of Set 14 | zlocieniec
# Processing Record 36 of Set 14 | tallahassee
# Processing Record 37 of Set 14 | manado
# Processing Record 38 of Set 14 | waingapu
# Processing Record 39 of Set 14 | songjianghe
# Processing Record 40 of Set 14 | gambo
# Processing Record 41 of Set 14 | langham
# Processing Record 42 of Set 14 | grindavik
# Processing Record 43 of Set 14 | obihiro
# Processing Record 44 of Set 14 | gazanjyk
# Processing Record 45 of Set 14 | cortland
# Processing Record 46 of Set 14 | taltal
# Processing Record 47 of Set 14 | deniliquin
# Processing Record 48 of Set 14 | mehran
# Processing Record 49 of Set 14 | andra
# Processing Record 50 of Set 14 | kamenka
# Processing Record 1 of Set 15 | khonuu
# City not found. Skipping...
# Processing Record 2 of Set 15 | sakakah
# Processing Record 3 of Set 15 | hirado
# Processing Record 4 of Set 15 | maple creek
# Processing Record 5 of Set 15 | kerki
# City not found. Skipping...
# Processing Record 6 of Set 15 | kangaatsiaq
# Processing Record 7 of Set 15 | kieta
# Processing Record 8 of Set 15 | araouane
# Processing Record 9 of Set 15 | oro valley
# Processing Record 10 of Set 15 | beisfjord
# Processing Record 11 of Set 15 | rio grande
# Processing Record 12 of Set 15 | oranjemund
# Processing Record 13 of Set 15 | bilibino
# Processing Record 14 of Set 15 | terrace
# Processing Record 15 of Set 15 | labutta
# City not found. Skipping...
# Processing Record 16 of Set 15 | atambua
# Processing Record 17 of Set 15 | xai-xai
# Processing Record 18 of Set 15 | praya
# Processing Record 19 of Set 15 | muros
# Processing Record 20 of Set 15 | axim
# Processing Record 21 of Set 15 | rock sound
# Processing Record 22 of Set 15 | fountain
# Processing Record 23 of Set 15 | puro
# Processing Record 24 of Set 15 | lithgow
# Processing Record 25 of Set 15 | biloela
# Processing Record 26 of Set 15 | scottsburgh
# City not found. Skipping...
# Processing Record 27 of Set 15 | bonavista
# Processing Record 28 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 29 of Set 15 | nhulunbuy
# Processing Record 30 of Set 15 | safaqis
# City not found. Skipping...
# Processing Record 31 of Set 15 | saint-francois
# Processing Record 32 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 33 of Set 15 | diepholz
# Processing Record 34 of Set 15 | batagay-alyta
# Processing Record 35 of Set 15 | horsham
# Processing Record 36 of Set 15 | krasne
# Processing Record 37 of Set 15 | bac lieu
# Processing Record 38 of Set 15 | soller
# Processing Record 39 of Set 15 | ilulissat
# Processing Record 40 of Set 15 | santa cruz
# Processing Record 41 of Set 15 | yar-sale
# Processing Record 42 of Set 15 | state college
# Processing Record 43 of Set 15 | oistins
# Processing Record 44 of Set 15 | tiksi
# Processing Record 45 of Set 15 | olds
# Processing Record 46 of Set 15 | xadani
# City not found. Skipping...
# Processing Record 47 of Set 15 | port washington
# Processing Record 48 of Set 15 | manjacaze
# Processing Record 49 of Set 15 | stupava
# Processing Record 50 of Set 15 | protvino
# Processing Record 1 of Set 16 | alto araguaia
# Processing Record 2 of Set 16 | merauke
# Processing Record 3 of Set 16 | orotukan
# Processing Record 4 of Set 16 | jiazi
# Processing Record 5 of Set 16 | honiara
# Processing Record 6 of Set 16 | yaizu
# Processing Record 7 of Set 16 | ipixuna
# Processing Record 8 of Set 16 | san miguel
# Processing Record 9 of Set 16 | mezhdurechensk
# Processing Record 10 of Set 16 | fare
# Processing Record 11 of Set 16 | skalistyy
# City not found. Skipping...
# Processing Record 12 of Set 16 | morrope
# Processing Record 13 of Set 16 | leh
# Processing Record 14 of Set 16 | tocopilla
# Processing Record 15 of Set 16 | taksimo
# Processing Record 16 of Set 16 | lower hutt
# Processing Record 17 of Set 16 | antofagasta
# Processing Record 18 of Set 16 | santa cruz de tenerife
# Processing Record 19 of Set 16 | filadelfia
# Processing Record 20 of Set 16 | matameye
# City not found. Skipping...
# Processing Record 21 of Set 16 | mugur-aksy
# Processing Record 22 of Set 16 | north platte
# Processing Record 23 of Set 16 | verishen
# Processing Record 24 of Set 16 | ilo
# Processing Record 25 of Set 16 | kirakira
# Processing Record 26 of Set 16 | kungalv
# Processing Record 27 of Set 16 | isiro
# Processing Record 28 of Set 16 | abnub
# Processing Record 29 of Set 16 | payo
# Processing Record 30 of Set 16 | along
# Processing Record 31 of Set 16 | shizunai
# Processing Record 32 of Set 16 | huarmey
# Processing Record 33 of Set 16 | khanewal
# Processing Record 34 of Set 16 | lesnoye
# Processing Record 35 of Set 16 | manzhouli
# Processing Record 36 of Set 16 | belmonte
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 726

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Alofi      NU -19.0595 -169.9187     67.89       100          79
# 1        Barcelos      PT  41.5388   -8.6151     57.85        44          75
# 2         Aksarka      RU  66.5606   67.7975      7.75        92          79
# 3       Busselton      AU -33.6500  115.3333     63.05        82          59
# 4     Deputatskiy      RU  69.3000  139.9000    -19.26        99          47
# 5  Puerto Carreno      CO   6.1890  -67.4859     89.58        58          40
# 6   San Cristobal      VE   7.7669  -72.2250     80.78        48          95
# 7    Punta Arenas      CL -53.1500  -70.9167     44.11        81          20
# 8          Avarua      CK -21.2078 -159.7750     73.45       100         100
# 9       Murchison      NZ -41.8000  172.3333     48.74        88           7
#
#    Wind Speed          Current Description
# 0        1.14                broken clouds
# 1        7.99                   light rain
# 2        7.25                broken clouds
# 3       14.97                broken clouds
# 4        2.39             scattered clouds
# 5        8.05             scattered clouds
# 6        6.51              overcast clouds
# 7       28.77  light intensity shower rain
# 8        1.14              overcast clouds
# 9        0.45                    clear sky

# %%
output_data_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label='City_ID')
